# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import fonctions
import embeddingsFunctions as ef
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
import networkx as nx
from node2vec import Node2Vec
from sklearn.model_selection import train_test_split
import umap
import seaborn as sns
from sklearn.cluster import KMeans
from collections import Counter
from matplotlib.lines import Line2D

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.preprocessing import LabelEncoder

# %%
#creation du fichier csv qui contient tous les tweets en faisant la somme de nobre de tweets
fichiers_csv=glob.glob(os.path.join('./sampleGraphs', "graph_*.csv"))

print(f" {len(fichiers_csv)} fichiers fusionner.")
liste_df=[]

for fichier in fichiers_csv:
        print(f"Lecture du fichier {fichier}...")
        df=pd.read_csv(fichier)
        liste_df.append(df)

df_global = pd.concat(liste_df, ignore_index=True)
df_grouped=df.groupby(['user_id', 'original_author'])['nb_retweeted'].sum().reset_index()
df_grouped.to_csv('graphe_complet_groupe.csv', index=False)
print(f"Fusion terminée. Taille finale : {len(df_grouped)} lignes.")
# Out:
#  59 fichiers fusionner.
# Lecture du fichier ./sampleGraphs/graph_2022-01-22_to_2022-02-04.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-02-12_to_2022-02-25.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-01-08_to_2022-01-28.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-03-12_to_2022-04-01.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-01-15_to_2022-02-04.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-02-26_to_2022-03-18.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-01-29_to_2022-02-18.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-01-22_to_2022-02-11.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-05-14_to_2022-06-03.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-04-30_to_2022-05-20.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-03-05_to_2022-03-25.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-05-21_to_2022-06-10.csv...
# Lecture du fichier ./sampleGraphs/graph_2022-03-26_to_2022-04-15.csv...
# ...

# %%
"""
#Creation du graphe 
G = nx.from_pandas_edgelist(df_grouped, 
                            source='user_id', 
                            target='original_author', 
                            edge_attr='nb_retweeted')



print(f"Le graphe final contient {G.number_of_nodes()} utilisateurs.")
    
    #Exploration :
node2vec=Node2Vec(G, dimensions=32, walk_length=10, num_walks=10, workers=2)

model=node2vec.fit(window=10, min_count=1, batch_words=4)

nodes =list(G.nodes)
embeddings=[model.wv[str(node)] for node in nodes]

pd_save=pd.DataFrame(embeddings, index=nodes)

pd_save.to_csv("embedings.csv")
embeddings = {str(nodes[i]): embeddings[i] for i in range(len(nodes))}
"""
# Out:
# Le graphe final contient 120707 utilisateurs.
# Computing transition probabilities:   0%|          | 0/120707 [00:00<?, ?it/s]

# %%
df_grouped=pd.read_csv('graphe_complet_groupe.csv')

# %%
G=ef.createGraphe(df_grouped)
# Out:
# Le graphe final contient 120707 utilisateurs.

# %%
ef.embedding32dimensions(G)
# Out:
# Computing transition probabilities:   0%|          | 0/120707 [00:00<?, ?it/s]
# KeyboardInterrupt
#
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7eff647b0800>>
# Traceback (most recent call last):
#   File "/home/bourenane/.local/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 797, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
ef.embedding64dimensions(G)

# %%
#lecture des deux fichier csv
#le fichier des etilisateurs tweeter
df_nodes = pd.read_csv('Nodes.csv', dtype={'Id': str})
#le fichier du resultats de l'entraînement node2vec 32 dimension (la premiere coleonne est les ids)
emb32 =pd.read_csv('embeddings32dimensions.csv') 
emb64=pd.read_csv('embeddings64dimensions.csv')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 142

# %%
# 2. Nettoyage des IDs pour les deux DataFrames
# On s'assure que la colonne ID est en texte propre (sans le .0)
for df in [emb32, emb64]:
    col_id = df.columns[0]
    df[col_id] = df[col_id].astype(float).apply(lambda x: '{:.0f}'.format(x))

# 3. Dictionnaire pour les couleurs (modularity_class)
mapping_dict = {str(k): v for k, v in zip(df_nodes['Id'], df_nodes['modularity_class'])}
labeled_ids = set(df_nodes['Id'].unique())

# 4. Filtrage : on ne garde que les nœuds présents dans Nodes.csv
emb32labeled = emb32[emb32[emb32.columns[0]].isin(labeled_ids)].reset_index(drop=True)
emb64labeled = emb64[emb64[emb64.columns[0]].isin(labeled_ids)].reset_index(drop=True)

# --- Pour les 32 dimensions ---
# On transforme le DataFrame filtré 32 en liste
liste_emb32 = emb32labeled.values.tolist()
train32, test32 = train_test_split(liste_emb32, test_size=0.20, random_state=42)

# --- Pour les 64 dimensions ---
# On transforme le DataFrame filtré 64 en liste
liste_emb64 = emb64labeled.values.tolist()
train64, test64 = train_test_split(liste_emb64, test_size=0.20, random_state=42)

# %%
# --- PRÉPARATION DES DONNÉES ---
#Non supervisé
# 32 Dimensions : On enlève l'ID (colonne 0)
train32_ = [row[1:] for row in train32]
test32_  = [row[1:] for row in test32]

# 64 Dimensions : On enlève l'ID (colonne 0)
train64_ = [row[1:] for row in train64]
test64_  = [row[1:] for row in test64]

# --- TRAITEMENT UMAP POUR 32 DIMENSIONS ---
print("Calcul UMAP pour 32 dimensions...")
reducer32 = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
train_emb32 = reducer32.fit_transform(train32_)
test_emb32  = reducer32.transform(test32_)

# --- TRAITEMENT UMAP POUR 64 DIMENSIONS ---
print("Calcul UMAP pour 64 dimensions...")
reducer64 = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
train_emb64 = reducer64.fit_transform(train64_)
test_emb64  = reducer64.transform(test64_)

print("Terminé !")
# Out:
# Calcul UMAP pour 32 dimensions...
# /home/bourenane/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Calcul UMAP pour 64 dimensions...
# /home/bourenane/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Terminé !

# %%
# Pour la version 32 dimensions
train_opinions32 = np.array([mapping_dict.get(str(row[0]), -1) for row in train32])
test_opinions32  = np.array([mapping_dict.get(str(row[0]), -1) for row in test32])

# Pour la version 64 dimensions
train_opinions64 = np.array([mapping_dict.get(str(row[0]), -1) for row in train64])
test_opinions64  = np.array([mapping_dict.get(str(row[0]), -1) for row in test64])

# %%
import matplotlib.pyplot as plt

# 1. On transforme les données avec UMAP (si ce n'est pas déjà fait)
# Supposons que 'u32' et 'u64' sont tes données réduites en 2D
# u32 = reducer.fit_transform(train_32_sans_id)
# u64 = reducer.fit_transform(train_64_sans_id)

# 2. Création de la figure avec 1 ligne et 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Graphique 1 : 32 Dimensions
scatter1 = ax1.scatter(train_emb32[:, 0], train_emb32[:, 1], c=train_opinions32, cmap='Spectral', s=5)
ax1.set_title('Visualisation des Embeddings (32 dims)')
ax1.set_xlabel('UMAP 1')
ax1.set_ylabel('UMAP 2')

# Graphique 2 : 64 Dimensions
scatter2 = ax2.scatter(train_emb64[:, 0], train_emb64[:, 1], c=train_opinions64, cmap='Spectral', s=5)
ax2.set_title('Visualisation des Embeddings (64 dims)')
ax2.set_xlabel('UMAP 1')

# Ajout d'une barre de légende pour les couleurs (communautés)
plt.colorbar(scatter2, ax=ax2, label='Modularity Class')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 1. On transforme les données avec UMAP (si ce n'est pas déjà fait)
# Supposons que 'u32' et 'u64' sont tes données réduites en 2D
# u32 = reducer.fit_transform(train_32_sans_id)
# u64 = reducer.fit_transform(train_64_sans_id)

# 2. Création de la figure avec 1 ligne et 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Graphique 1 : 32 Dimensions
scatter1 = ax1.scatter(train_emb32[:, 0], train_emb32[:, 1], c=train_opinions32, cmap='Spectral', s=5)
ax1.set_title('Visualisation des Embeddings (32 dims)')
ax1.set_xlabel('UMAP 1')
ax1.set_ylabel('UMAP 2')

# Graphique 2 : 64 Dimensions
scatter2 = ax2.scatter(train_emb64[:, 0], train_emb64[:, 1], c=train_opinions64, cmap='Spectral', s=5)
ax2.set_title('Visualisation des Embeddings (64 dims)')
ax2.set_xlabel('UMAP 1')

# Ajout d'une barre de légende pour les couleurs (communautés)
plt.colorbar(scatter2, ax=ax2, label='Modularity Class')

plt.tight_layout()
plt.show()

# %%
# --- CALCUL ET AFFICHAGE POUR 32 DIMENSIONS ---
print("--- Analyse du modèle 32 dimensions ---")
# Utilise train_emb32 (le résultat d'UMAP) et train_opinions32
pre_n_train32 = fonctions.barycenter_precision2(train_emb32, train_opinions32)
print(f"La précision pour 32 dims est : {pre_n_train32:.4f}\n")

# --- CALCUL ET AFFICHAGE POUR 64 DIMENSIONS ---
print("--- Analyse du modèle 64 dimensions ---")
# Utilise train_emb64 (le résultat d'UMAP) et train_opinions64
pre_n_train64 = fonctions.barycenter_precision2(train_emb64, train_opinions64)
print(f"La précision pour 64 dims est : {pre_n_train64:.4f}\n")

# --- COMPARAISON FINALE ---
print("-" * 30)
diff = pre_n_train64 - pre_n_train32
if diff > 0:
    print(f"Le modèle 64 dimensions est meilleur de {diff:.4f}")
else:
    print(f"Le modèle 32 dimensions est aussi bon ou meilleur (diff: {diff:.4f})")
# Out:
# --- Analyse du modèle 32 dimensions ---
# La précision pour 32 dims est : 0.9969
#
# --- Analyse du modèle 64 dimensions ---
# La précision pour 64 dims est : 0.9969
#
# ------------------------------
# Le modèle 32 dimensions est aussi bon ou meilleur (diff: 0.0000)

# %%
# --- CALCUL ET AFFICHAGE POUR 32 DIMENSIONS ---
print("--- Analyse du modèle 32 dimensions ---")
# Utilise train_emb32 (le résultat d'UMAP) et train_opinions32
pre_n_train32 = fonctions.barycenter_precision2(train_emb32, train_opinions32)
print(f"La précision pour 32 dims est : {pre_n_train32:.4f}\n")

# --- CALCUL ET AFFICHAGE POUR 64 DIMENSIONS ---
print("--- Analyse du modèle 64 dimensions ---")
# Utilise train_emb64 (le résultat d'UMAP) et train_opinions64
pre_n_train64 = fonctions.barycenter_precision2(train_emb64, train_opinions64)
print(f"La précision pour 64 dims est : {pre_n_train64:.4f}\n")

# --- COMPARAISON FINALE ---
print("-" * 30)
diff = pre_n_train64 - pre_n_train32
if diff > 0:
    print(f"Le modèle 64 dimensions est meilleur de {diff:.4f}")
else:
    print(f"Le modèle 32 dimensions est aussi bon ou meilleur (diff: {diff:.4f})")
# Out:
# --- Analyse du modèle 32 dimensions ---
# La précision pour 32 dims est : 0.9969
#
# --- Analyse du modèle 64 dimensions ---
# La précision pour 64 dims est : 0.9969
#
# ------------------------------
# Le modèle 32 dimensions est aussi bon ou meilleur (diff: 0.0000)

# %%
import matplotlib.pyplot as plt

# 1. Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Graphique de gauche : TEST 32 Dimensions ---
# On utilise test_emb32 (la projection UMAP du test)
scatter1 = ax1.scatter(
    test_emb32[:, 0], 
    test_emb32[:, 1], 
    c=test_opinions32, 
    cmap='Spectral', 
    s=12,         # Points légèrement plus gros car il y a moins de données en test
    alpha=0.7
)
ax1.set_title('TEST : Embeddings 32 dimensions', fontsize=14)
ax1.set_xlabel('UMAP Axe 1')
ax1.set_ylabel('UMAP Axe 2')
ax1.grid(True, linestyle='--', alpha=0.3)

# --- Graphique de droite : TEST 64 Dimensions ---
# On utilise test_emb64 (la projection UMAP du test)
scatter2 = ax2.scatter(
    test_emb64[:, 0], 
    test_emb64[:, 1], 
    c=test_opinions64, 
    cmap='Spectral', 
    s=12, 
    alpha=0.7
)
ax2.set_title('TEST : Embeddings 64 dimensions', fontsize=14)
ax2.set_xlabel('UMAP Axe 1')
ax2.grid(True, linestyle='--', alpha=0.3)

# 2. Ajout de la barre de couleur
cbar = plt.colorbar(scatter2, ax=ax2)
cbar.set_label('Opinions / Modularity Class', rotation=270, labelpad=15)

# Titre général
plt.suptitle("Comparaison visuelle des populations de TEST (20% des données)", fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

# 1. Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Graphique de gauche : TEST 32 Dimensions ---
# On utilise test_emb32 (la projection UMAP du test)
scatter1 = ax1.scatter(
    test_emb32[:, 0], 
    test_emb32[:, 1], 
    c=test_opinions32, 
    cmap='Spectral', 
    s=12,         # Points légèrement plus gros car il y a moins de données en test
    alpha=0.7
)
ax1.set_title('TEST : Embeddings 32 dimensions', fontsize=14)
ax1.set_xlabel('UMAP Axe 1')
ax1.set_ylabel('UMAP Axe 2')
ax1.grid(True, linestyle='--', alpha=0.3)

# --- Graphique de droite : TEST 64 Dimensions ---
# On utilise test_emb64 (la projection UMAP du test)
scatter2 = ax2.scatter(
    test_emb64[:, 0], 
    test_emb64[:, 1], 
    c=test_opinions64, 
    cmap='Spectral', 
    s=12, 
    alpha=0.7
)
ax2.set_title('TEST : Embeddings 64 dimensions', fontsize=14)
ax2.set_xlabel('UMAP Axe 1')
ax2.grid(True, linestyle='--', alpha=0.3)

# 2. Ajout de la barre de couleur
cbar = plt.colorbar(scatter2, ax=ax2)
cbar.set_label('Opinions / Modularity Class', rotation=270, labelpad=15)

# Titre général
plt.suptitle("Comparaison visuelle des populations de TEST (20% des données)", fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# --- CALCUL DE PRÉCISION SUR LE TEST - 32 DIMENSIONS ---
print("--- Évaluation TEST : 32 dimensions ---")
# On utilise test_emb32 (coordonnées UMAP) et test_opinions32 (vrais labels)
pre_n_test32 = fonctions.barycenter_precision2(test_emb32, test_opinions32)
print(f"La précision sur le TEST (32 dims) est : {pre_n_test32:.4f}\n")

# --- CALCUL DE PRÉCISION SUR LE TEST - 64 DIMENSIONS ---
print("--- Évaluation TEST : 64 dimensions ---")
# On utilise test_emb64 (coordonnées UMAP) et test_opinions64 (vrais labels)
pre_n_test64 = fonctions.barycenter_precision2(test_emb64, test_opinions64)
print(f"La précision sur le TEST (64 dims) est : {pre_n_test64:.4f}\n")

# --- COMPARAISON DES PERFORMANCES ---
print("-" * 30)
if pre_n_test64 > pre_n_test32:
    gain = (pre_n_test64 - pre_n_test32) * 100
    print(f"Le passage à 64 dimensions améliore la précision de {gain:.2f}%")
else:
    print("Les 64 dimensions n'apportent pas d'amélioration significative sur le test.")
# Out:
# --- Évaluation TEST : 32 dimensions ---
# La précision sur le TEST (32 dims) est : 0.9756
#
# --- Évaluation TEST : 64 dimensions ---
# La précision sur le TEST (64 dims) est : 0.9634
#
# ------------------------------
# Les 64 dimensions n'apportent pas d'amélioration significative sur le test.

# %%
# --- CALCUL DE PRÉCISION SUR LE TEST - 32 DIMENSIONS ---
print("--- Évaluation TEST : 32 dimensions ---")
# On utilise test_emb32 (coordonnées UMAP) et test_opinions32 (vrais labels)
pre_n_test32 = fonctions.barycenter_precision2(test_emb32, test_opinions32)
print(f"La précision sur le TEST (32 dims) est : {pre_n_test32:.4f}\n")

# --- CALCUL DE PRÉCISION SUR LE TEST - 64 DIMENSIONS ---
print("--- Évaluation TEST : 64 dimensions ---")
# On utilise test_emb64 (coordonnées UMAP) et test_opinions64 (vrais labels)
pre_n_test64 = fonctions.barycenter_precision2(test_emb64, test_opinions64)
print(f"La précision sur le TEST (64 dims) est : {pre_n_test64:.4f}\n")

# --- COMPARAISON DES PERFORMANCES ---
print("-" * 30)
if pre_n_test64 > pre_n_test32:
    gain = (pre_n_test64 - pre_n_test32) * 100
    print(f"Le passage à 64 dimensions améliore la précision de {gain:.2f}%")
else:
    print("Les 64 dimensions n'apportent pas d'amélioration significative sur le test.")
# Out:
# --- Évaluation TEST : 32 dimensions ---
# La précision sur le TEST (32 dims) est : 0.9756
#
# --- Évaluation TEST : 64 dimensions ---
# La précision sur le TEST (64 dims) est : 0.9634
#
# ------------------------------
# Les 64 dimensions n'apportent pas d'amélioration significative sur le test.

# %%
# ==========================================
# ANALYSE DU MODÈLE 32 DIMENSIONS
# ==========================================
print("--- Évaluation 32 dimensions (Calcul sur Train, Application sur Test) ---")

# 1. On fixe la transformation sur le TRAIN 32
transform_32 = fonctions.compute_barycenter_transform(train_emb32, train_opinions32)

# 2. On applique sur le TRAIN 32 (pour vérification)
acc_train32 = fonctions.apply_barycenter_transform(
    train_emb32, transform_32, train_opinions32, title="Train 32D (Référence)"
)

# 3. On applique sur le TEST 32 (à l'aveugle)
acc_test32 = fonctions.apply_barycenter_transform(
    test_emb32, transform_32, test_opinions32, title="Test 32D (Généralisation)"
)


# ==========================================
# ANALYSE DU MODÈLE 64 DIMENSIONS
# ==========================================
print("\n--- Évaluation 64 dimensions (Calcul sur Train, Application sur Test) ---")

# 1. On fixe la transformation sur le TRAIN 64
transform_64 = fonctions.compute_barycenter_transform(train_emb64, train_opinions64)

# 2. On applique sur le TRAIN 64
acc_train64 = fonctions.apply_barycenter_transform(
    train_emb64, transform_64, train_opinions64, title="Train 64D (Référence)"
)

# 3. On applique sur le TEST 64 (à l'aveugle)
acc_test64 = fonctions.apply_barycenter_transform(
    test_emb64, transform_64, test_opinions64, title="Test 64D (Généralisation)"
)

# ==========================================
# RÉSUMÉ DES PERFORMANCES
# ==========================================
print("\n" + "="*40)
print(f"SCORE FINAL TEST 32D : {acc_test32:.4f}")
print(f"SCORE FINAL TEST 64D : {acc_test64:.4f}")
print("="*40)
# Out:
# --- Évaluation 32 dimensions (Calcul sur Train, Application sur Test) ---
# --- Évaluation 64 dimensions (Calcul sur Train, Application sur Test) ---
# ...
# SCORE FINAL TEST 32D : 0.9756
# SCORE FINAL TEST 64D : 0.9634
# ...

# %%
# ==========================================
# ANALYSE DU MODÈLE 32 DIMENSIONS
# ==========================================
print("--- Évaluation 32 dimensions (Calcul sur Train, Application sur Test) ---")

# 1. On fixe la transformation sur le TRAIN 32
transform_32 = fonctions.compute_barycenter_transform(train_emb32, train_opinions32)

# 2. On applique sur le TRAIN 32 (pour vérification)
acc_train32 = fonctions.apply_barycenter_transform(
    train_emb32, transform_32, train_opinions32, title="Train 32D (Référence)"
)

# 3. On applique sur le TEST 32 (à l'aveugle)
acc_test32 = fonctions.apply_barycenter_transform(
    test_emb32, transform_32, test_opinions32, title="Test 32D (Généralisation)"
)


# ==========================================
# ANALYSE DU MODÈLE 64 DIMENSIONS
# ==========================================
print("\n--- Évaluation 64 dimensions (Calcul sur Train, Application sur Test) ---")

# 1. On fixe la transformation sur le TRAIN 64
transform_64 = fonctions.compute_barycenter_transform(train_emb64, train_opinions64)

# 2. On applique sur le TRAIN 64
acc_train64 = fonctions.apply_barycenter_transform(
    train_emb64, transform_64, train_opinions64, title="Train 64D (Référence)"
)

# 3. On applique sur le TEST 64 (à l'aveugle)
acc_test64 = fonctions.apply_barycenter_transform(
    test_emb64, transform_64, test_opinions64, title="Test 64D (Généralisation)"
)

# ==========================================
# RÉSUMÉ DES PERFORMANCES
# ==========================================
print("\n" + "="*40)
print(f"SCORE FINAL TEST 32D : {acc_test32:.4f}")
print(f"SCORE FINAL TEST 64D : {acc_test64:.4f}")
print("="*40)
# Out:
# --- Évaluation 32 dimensions (Calcul sur Train, Application sur Test) ---
# --- Évaluation 64 dimensions (Calcul sur Train, Application sur Test) ---
# ...
# SCORE FINAL TEST 32D : 0.9756
# SCORE FINAL TEST 64D : 0.9634
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# ==========================================
# KNN SUR LE MODÈLE 32 DIMENSIONS
# ==========================================
print("--- Évaluation KNN : 32 dimensions ---")

# 1. Initialisation du classifieur (on regarde les 5 voisins les plus proches)
knn32 = KNeighborsClassifier(n_neighbors=5)

# 2. Apprentissage sur le Train 32 (coordonnées UMAP + opinions)
knn32.fit(train_emb32, train_opinions32)

# 3. Prédiction sur le Test 32
y_pred32 = knn32.predict(test_emb32)

# 4. Score final
acc_knn32 = accuracy_score(test_opinions32, y_pred32)
print(f"Accuracy KNN (32 dims) : {acc_knn32:.4f}\n")


# ==========================================
# KNN SUR LE MODÈLE 64 DIMENSIONS
# ==========================================
print("--- Évaluation KNN : 64 dimensions ---")

# 1. Initialisation
knn64 = KNeighborsClassifier(n_neighbors=5)

# 2. Apprentissage sur le Train 64
knn64.fit(train_emb64, train_opinions64)

# 3. Prédiction sur le Test 64
y_pred64 = knn64.predict(test_emb64)

# 4. Score final
acc_knn64 = accuracy_score(test_opinions64, y_pred64)
print(f"Accuracy KNN (64 dims) : {acc_knn64:.4f}\n")

# ==========================================
# COMPARAISON FINALE DES MÉTHODES
# ==========================================
print("-" * 30)
print(f"RÉSUMÉ KNN - 32 dims: {acc_knn32:.4f} | 64 dims: {acc_knn64:.4f}")
# Out:
# --- Évaluation KNN : 32 dimensions ---
# Accuracy KNN (32 dims) : 0.9756
#
# --- Évaluation KNN : 64 dimensions ---
# Accuracy KNN (64 dims) : 0.9634
#
# ------------------------------
# RÉSUMÉ KNN - 32 dims: 0.9756 | 64 dims: 0.9634

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# ==========================================
# KNN SUR LE MODÈLE 32 DIMENSIONS
# ==========================================
print("--- Évaluation KNN : 32 dimensions ---")

# 1. Initialisation du classifieur (on regarde les 5 voisins les plus proches)
knn32 = KNeighborsClassifier(n_neighbors=5)

# 2. Apprentissage sur le Train 32 (coordonnées UMAP + opinions)
knn32.fit(train_emb32, train_opinions32)

# 3. Prédiction sur le Test 32
y_pred32 = knn32.predict(test_emb32)

# 4. Score final
acc_knn32 = accuracy_score(test_opinions32, y_pred32)
print(f"Accuracy KNN (32 dims) : {acc_knn32:.4f}\n")


# ==========================================
# KNN SUR LE MODÈLE 64 DIMENSIONS
# ==========================================
print("--- Évaluation KNN : 64 dimensions ---")

# 1. Initialisation
knn64 = KNeighborsClassifier(n_neighbors=5)

# 2. Apprentissage sur le Train 64
knn64.fit(train_emb64, train_opinions64)

# 3. Prédiction sur le Test 64
y_pred64 = knn64.predict(test_emb64)

# 4. Score final
acc_knn64 = accuracy_score(test_opinions64, y_pred64)
print(f"Accuracy KNN (64 dims) : {acc_knn64:.4f}\n")

# ==========================================
# COMPARAISON FINALE DES MÉTHODES
# ==========================================
print("-" * 30)
print(f"RÉSUMÉ KNN - 32 dims: {acc_knn32:.4f} | 64 dims: {acc_knn64:.4f}")
# Out:
# --- Évaluation KNN : 32 dimensions ---
# Accuracy KNN (32 dims) : 0.9756
#
# --- Évaluation KNN : 64 dimensions ---
# Accuracy KNN (64 dims) : 0.9634
#
# ------------------------------
# RÉSUMÉ KNN - 32 dims: 0.9756 | 64 dims: 0.9634

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Définition des étiquettes pour les axes
labels = ['Sceptique (0)', 'Pro-climat (4)']

# Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# --- Matrice 32D ---
cm32 = confusion_matrix(test_opinions32, y_pred32)
disp32 = ConfusionMatrixDisplay(confusion_matrix=cm32, display_labels=labels)

disp32.plot(ax=ax1, cmap='Blues', colorbar=False)
ax1.set_title("KNN 32 Dimensions (Non-Sup)")

cm32 = confusion_matrix(test_opinions32, y_pred32)
disp32 = ConfusionMatrixDisplay(confusion_matrix=cm32, display_labels=labels)

disp32.plot(ax=ax1, cmap='Blues', colorbar=False)
ax1.set_title("BaryCentre 32 Dimensions (Non-Sup)")

# --- Matrice 64D ---
cm64 = confusion_matrix(test_opinions64, y_pred64)
disp64 = ConfusionMatrixDisplay(confusion_matrix=cm64, display_labels=labels)

disp64.plot(ax=ax2, cmap='Blues', colorbar=False)
ax2.set_title("KNN 64 Dimensions (Non-Sup)")
"""
cm64 = confusion_matrix(test_emb64, y_pred64)
disp64 = ConfusionMatrixDisplay(confusion_matrix=cm64, display_labels=labels)

disp64.plot(ax=ax2, cmap='Blues', colorbar=False)
ax2.set_title("Barycentre 64 Dimensions (Non-Sup)")"""

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Définition des étiquettes pour les axes
labels = ['Sceptique (0)', 'Pro-climat (4)']

# Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# --- Matrice 32D ---
cm32 = confusion_matrix(test_opinions32, y_pred32)
disp32 = ConfusionMatrixDisplay(confusion_matrix=cm32, display_labels=labels)

disp32.plot(ax=ax1, cmap='Blues', colorbar=False)
ax1.set_title("KNN 32 Dimensions (Non-Sup)")

# --- Matrice 64D ---
cm64 = confusion_matrix(test_opinions64, y_pred64)
disp64 = ConfusionMatrixDisplay(confusion_matrix=cm64, display_labels=labels)

disp64.plot(ax=ax2, cmap='Blues', colorbar=False)
ax2.set_title("KNN 64 Dimensions (Non-Sup)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ==================================================================================================================================
# Après avoir exploré la structure géométrique du graphe de manière non supervisée (réduction de dimension UMAP et alignement des barycentres), nous changeons d'approche

# %% [markdown]
# Maintenant que nous avons visualisé la structure du graphe en non supervisé ,nous allons utiliser les 'labels' (opinions connues) pour entraîner

# %%
# --- TRAITEMENT UMAP SUPERVISÉ POUR 32 DIMENSIONS ---
print("Calcul UMAP SUPERVISÉ pour 32 dimensions...")
# On crée le reducer
reducer32_sup = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)

# LA DIFFÉRENCE EST ICI : On donne 'train_opinions32' au moment du fit
train_emb32 = reducer32_sup.fit_transform(train32_, y=train_opinions32)

# Pour le test, on ne donne PAS les labels (on veut voir si le modèle a appris la règle)
test_emb32 = reducer32_sup.transform(test32_)


# --- TRAITEMENT UMAP SUPERVISÉ POUR 64 DIMENSIONS ---
print("Calcul UMAP SUPERVISÉ pour 64 dimensions...")
reducer64_sup = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)

# Idem : on passe les labels du train
train_emb64 = reducer64_sup.fit_transform(train64_, y=train_opinions64)

# Transformation du test à l'aveugle
test_emb64 = reducer64_sup.transform(test64_)

print("Terminé ! Le clustering est maintenant guidé par les opinions.")
# Out:
# Calcul UMAP SUPERVISÉ pour 32 dimensions...
# /home/bourenane/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Calcul UMAP SUPERVISÉ pour 64 dimensions...
# /home/bourenane/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Terminé ! Le clustering est maintenant guidé par les opinions.

# %%
import matplotlib.pyplot as plt

# 1. Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Graphique de gauche : TEST 32 Dimensions ---
# On utilise test_emb32 (la projection UMAP supervisée du test)
scatter1 = ax1.scatter(
    test_emb32[:, 0], 
    test_emb32[:, 1], 
    c=test_opinions32, 
    cmap='Spectral', 
    s=15,          # Un peu plus gros pour bien voir la séparation sur le test
    alpha=0.7
)
ax1.set_title('TEST Supervisé : Embeddings 32 dimensions', fontsize=14)
ax1.set_xlabel('UMAP Axe 1')
ax1.set_ylabel('UMAP Axe 2')
ax1.grid(True, linestyle='--', alpha=0.3)

# --- Graphique de droite : TEST 64 Dimensions ---
# On utilise test_emb64 (la projection UMAP supervisée du test)
scatter2 = ax2.scatter(
    test_emb64[:, 0], 
    test_emb64[:, 1], 
    c=test_opinions64, 
    cmap='Spectral', 
    s=15, 
    alpha=0.7
)
ax2.set_title('TEST Supervisé : Embeddings 64 dimensions', fontsize=14)
ax2.set_xlabel('UMAP Axe 1')
ax2.grid(True, linestyle='--', alpha=0.3)

# 2. Ajout de la barre de couleur
cbar = plt.colorbar(scatter2, ax=ax2)
cbar.set_label('Opinions / Modularity Class', rotation=270, labelpad=15)

# Titre général
plt.suptitle("Comparaison du TEST après UMAP Supervisé (32 vs 64 dims)", fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

# 1. Création de la figure : 1 ligne, 2 colonnes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Graphique de gauche : TEST 32 Dimensions ---
# On utilise test_emb32 (la projection UMAP supervisée du test)
scatter1 = ax1.scatter(
    test_emb32[:, 0], 
    test_emb32[:, 1], 
    c=test_opinions32, 
    cmap='Spectral', 
    s=15,          # Un peu plus gros pour bien voir la séparation sur le test
    alpha=0.7
)
ax1.set_title('TEST Supervisé : Embeddings 32 dimensions', fontsize=14)
ax1.set_xlabel('UMAP Axe 1')
ax1.set_ylabel('UMAP Axe 2')
ax1.grid(True, linestyle='--', alpha=0.3)

# --- Graphique de droite : TEST 64 Dimensions ---
# On utilise test_emb64 (la projection UMAP supervisée du test)
scatter2 = ax2.scatter(
    test_emb64[:, 0], 
    test_emb64[:, 1], 
    c=test_opinions64, 
    cmap='Spectral', 
    s=15, 
    alpha=0.7
)
ax2.set_title('TEST Supervisé : Embeddings 64 dimensions', fontsize=14)
ax2.set_xlabel('UMAP Axe 1')
ax2.grid(True, linestyle='--', alpha=0.3)

# 2. Ajout de la barre de couleur
cbar = plt.colorbar(scatter2, ax=ax2)
cbar.set_label('Opinions / Modularity Class', rotation=270, labelpad=15)

# Titre général
plt.suptitle("Comparaison du TEST après UMAP Supervisé (32 vs 64 dims)", fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# --- CALCUL DE PRÉCISION : TRAIN SUPERVISÉ 32 DIMENSIONS ---
print("--- Évaluation Train Supervisé : 32 dimensions ---")
# On utilise train_emb32 (issu du fit_transform supervisé)
pre_s_train32 = fonctions.barycenter_precision2(train_emb32, train_opinions32)
print(f"La précision (Train 32 dims) est : {pre_s_train32:.4f}\n")

# --- CALCUL DE PRÉCISION : TRAIN SUPERVISÉ 64 DIMENSIONS ---
print("--- Évaluation Train Supervisé : 64 dimensions ---")
# On utilise train_emb64 (issu du fit_transform supervisé)
pre_s_train64 = fonctions.barycenter_precision2(train_emb64, train_opinions64)
print(f"La précision (Train 64 dims) est : {pre_s_train64:.4f}\n")

# --- COMPARAISON DES RÉSULTATS ---
print("-" * 40)
print(f"RÉSUMÉ TRAIN SUPERVISÉ :")
print(f"32 Dims : {pre_s_train32:.4f}")
print(f"64 Dims : {pre_s_train64:.4f}")
# Out:
# --- Évaluation Train Supervisé : 32 dimensions ---
# La précision (Train 32 dims) est : 1.0000
#
# --- Évaluation Train Supervisé : 64 dimensions ---
# La précision (Train 64 dims) est : 1.0000
#
# ----------------------------------------
# RÉSUMÉ TRAIN SUPERVISÉ :
# 32 Dims : 1.0000
# 64 Dims : 1.0000

# %%
# --- CALCUL DE PRÉCISION : TRAIN SUPERVISÉ 32 DIMENSIONS ---
print("--- Évaluation Train Supervisé : 32 dimensions ---")
# On utilise train_emb32 (issu du fit_transform supervisé)
pre_s_train32 = fonctions.barycenter_precision2(train_emb32, train_opinions32)
print(f"La précision (Train 32 dims) est : {pre_s_train32:.4f}\n")

# --- CALCUL DE PRÉCISION : TRAIN SUPERVISÉ 64 DIMENSIONS ---
print("--- Évaluation Train Supervisé : 64 dimensions ---")
# On utilise train_emb64 (issu du fit_transform supervisé)
pre_s_train64 = fonctions.barycenter_precision2(train_emb64, train_opinions64)
print(f"La précision (Train 64 dims) est : {pre_s_train64:.4f}\n")

# --- COMPARAISON DES RÉSULTATS ---
print("-" * 40)
print(f"RÉSUMÉ TRAIN SUPERVISÉ :")
print(f"32 Dims : {pre_s_train32:.4f}")
print(f"64 Dims : {pre_s_train64:.4f}")
# Out:
# --- Évaluation Train Supervisé : 32 dimensions ---
# La précision (Train 32 dims) est : 1.0000
#
# --- Évaluation Train Supervisé : 64 dimensions ---
# La précision (Train 64 dims) est : 1.0000
#
# ----------------------------------------
# RÉSUMÉ TRAIN SUPERVISÉ :
# 32 Dims : 1.0000
# 64 Dims : 1.0000

# %%
# --- CALCUL DE PRÉCISION : TEST SUPERVISÉ 32 DIMENSIONS ---
print("--- Évaluation Test Supervisé : 32 dimensions ---")
# On utilise test_emb32 (la projection du test via le reducer supervisé)
pre_s_test32 = fonctions.barycenter_precision2(test_emb32, test_opinions32)
print(f"La précision sur le TEST (32 dims) est : {pre_s_test32:.4f}\n")

# --- CALCUL DE PRÉCISION : TEST SUPERVISÉ 64 DIMENSIONS ---
print("--- Évaluation Test Supervisé : 64 dimensions ---")
# On utilise test_emb64 (la projection du test via le reducer supervisé)
pre_s_test64 = fonctions.barycenter_precision2(test_emb64, test_opinions64)
print(f"La précision sur le TEST (64 dims) est : {pre_s_test64:.4f}\n")

# --- COMPARAISON FINALE DES PERFORMANCES ---
print("="*50)
print(f"RÉSUMÉ DES SCORES SUR LE TEST :")
print(f"Précision 32 Dimensions : {pre_s_test32:.4f}")
print(f"Précision 64 Dimensions : {pre_s_test64:.4f}")
print("="*50)

diff = pre_s_test64 - pre_s_test32
if diff > 0:
    print(f"Le modèle 64 dimensions gagne avec un écart de {diff*100:.2f}%")
else:
    print(f"Le modèle 32 dimensions reste le plus efficace (écart : {diff*100:.2f}%)")
# Out:
# --- Évaluation Test Supervisé : 32 dimensions ---
# La précision sur le TEST (32 dims) est : 0.9756
#
# --- Évaluation Test Supervisé : 64 dimensions ---
# La précision sur le TEST (64 dims) est : 0.9756
#
# ...
# RÉSUMÉ DES SCORES SUR LE TEST :
# Précision 32 Dimensions : 0.9756
# Précision 64 Dimensions : 0.9756
# ...
# Le modèle 32 dimensions reste le plus efficace (écart : 0.00%)

# %%
# --- CALCUL DE PRÉCISION : TEST SUPERVISÉ 32 DIMENSIONS ---
print("--- Évaluation Test Supervisé : 32 dimensions ---")
# On utilise test_emb32 (la projection du test via le reducer supervisé)
pre_s_test32 = fonctions.barycenter_precision2(test_emb32, test_opinions32)
print(f"La précision sur le TEST (32 dims) est : {pre_s_test32:.4f}\n")

# --- CALCUL DE PRÉCISION : TEST SUPERVISÉ 64 DIMENSIONS ---
print("--- Évaluation Test Supervisé : 64 dimensions ---")
# On utilise test_emb64 (la projection du test via le reducer supervisé)
pre_s_test64 = fonctions.barycenter_precision2(test_emb64, test_opinions64)
print(f"La précision sur le TEST (64 dims) est : {pre_s_test64:.4f}\n")

# --- COMPARAISON FINALE DES PERFORMANCES ---
print("="*50)
print(f"RÉSUMÉ DES SCORES SUR LE TEST :")
print(f"Précision 32 Dimensions : {pre_s_test32:.4f}")
print(f"Précision 64 Dimensions : {pre_s_test64:.4f}")
print("="*50)

diff = pre_s_test64 - pre_s_test32
if diff > 0:
    print(f"Le modèle 64 dimensions gagne avec un écart de {diff*100:.2f}%")
else:
    print(f"Le modèle 32 dimensions reste le plus efficace (écart : {diff*100:.2f}%)")
# Out:
# --- Évaluation Test Supervisé : 32 dimensions ---
# La précision sur le TEST (32 dims) est : 0.9756
#
# --- Évaluation Test Supervisé : 64 dimensions ---
# La précision sur le TEST (64 dims) est : 0.9756
#
# ...
# RÉSUMÉ DES SCORES SUR LE TEST :
# Précision 32 Dimensions : 0.9756
# Précision 64 Dimensions : 0.9756
# ...
# Le modèle 32 dimensions reste le plus efficace (écart : 0.00%)

# %%
#calcul de presision avec les barycentre
pre_s_test=fonctions.barycenter_precision2(test_emb_sup,test_opinions_np)
print("la presicion est ",pre_s_test,"\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 #calcul de presision avec les barycentre
# ----> 2 pre_s_test=fonctions.barycenter_precision2(test_emb_sup,test_opinions_np)
#       3 print("la presicion est ",pre_s_test,"\n")
#
# NameError: name 'test_emb_sup' is not defined

# %%
# ============================================================
# ANALYSE COMPARATIVE SUPERVISÉE (32 vs 64 DIMENSIONS)
# ============================================================

# --- 1. TRAITEMENT 32 DIMENSIONS ---
print("--- Analyse 32 Dimensions ---")

# Calcul de la transformation géométrique basée sur le TRAIN
transform_s32 = fonctions.compute_barycenter_transform(train_emb32, train_opinions32)

# Application sur le TRAIN (Vérification de la séparation)
acc_s_train32 = fonctions.apply_barycenter_transform(
    train_emb32, transform_s32, train_opinions32, title="Train 32D Supervisé"
)

# Application sur le TEST (Généralisation à l'aveugle)
acc_s_test32 = fonctions.apply_barycenter_transform(
    test_emb32, transform_s32, test_opinions32, title="Test 32D Supervisé"
)


# --- 2. TRAITEMENT 64 DIMENSIONS ---
print("\n--- Analyse 64 Dimensions ---")

# Calcul de la transformation géométrique basée sur le TRAIN
transform_s64 = fonctions.compute_barycenter_transform(train_emb64, train_opinions64)

# Application sur le TRAIN
acc_s_train64 = fonctions.apply_barycenter_transform(
    train_emb64, transform_s64, train_opinions64, title="Train 64D Supervisé"
)

# Application sur le TEST
acc_s_test64 = fonctions.apply_barycenter_transform(
    test_emb64, transform_s64, test_opinions64, title="Test 64D Supervisé"
)

# --- 3. RÉSUMÉ FINAL DES SCORES ---
print("\n" + "="*50)
print(f"RÉSULTATS FINAUX (Accuracy sur Test Set)")
print(f"Modèle 32 Dimensions : {acc_s_test32:.4f}")
print(f"Modèle 64 Dimensions : {acc_s_test64:.4f}")
print("="*50)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# ==========================================
# KNN SUR UMAP SUPERVISÉ - 32 DIMENSIONS
# ==========================================
print("--- Évaluation KNN : 32 dimensions (Supervisé) ---")

knn32 = KNeighborsClassifier(n_neighbors=5)
# Entraînement sur le Train Supervisé
knn32.fit(train_emb32, train_opinions32)

# Prédiction sur le Test (Projeté via le transform supervisé)
y_pred32 = knn32.predict(test_emb32)

print(f"Accuracy KNN 32D : {accuracy_score(test_opinions32, y_pred32):.4f}")
print(classification_report(test_opinions32, y_pred32))


# ==========================================
# KNN SUR UMAP SUPERVISÉ - 64 DIMENSIONS
# ==========================================
print("\n--- Évaluation KNN : 64 dimensions (Supervisé) ---")

knn64 = KNeighborsClassifier(n_neighbors=5)
# Entraînement sur le Train Supervisé
knn64.fit(train_emb64, train_opinions64)

# Prédiction sur le Test
y_pred64 = knn64.predict(test_emb64)

print(f"Accuracy KNN 64D : {accuracy_score(test_opinions64, y_pred64):.4f}")
print(classification_report(test_opinions64, y_pred64))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Matrice 32D
cm32 = confusion_matrix(test_opinions32, y_pred32)
disp32 = ConfusionMatrixDisplay(confusion_matrix=cm32, display_labels=labels)
disp32.plot(ax=ax1, cmap='Blues', colorbar=False)
ax1.set_title("KNN 32 Dimensions")

# Matrice 64D
cm64 = confusion_matrix(test_opinions64, y_pred64)
disp64 = ConfusionMatrixDisplay(confusion_matrix=cm64, display_labels=labels)
disp64.plot(ax=ax2, cmap='Blues', colorbar=False)
ax2.set_title("KNN 64 Dimensions")

plt.tight_layout()
plt.show()

# %%
import networkx as nx
import community as community_louvain  
import numpy as np
from collections import Counter

G = nx.from_pandas_edgelist(df_grouped, 
                            source='user_id', 
                            target='original_author', 
                            edge_attr='nb_retweeted')

partition = community_louvain.best_partition(G)



comm_sizes = Counter(partition.values())
top2 = [c for c, _ in comm_sizes.most_common(2)]
comm_A = [n for n, c in partition.items() if c == top2[0]]
comm_B = [n for n, c in partition.items() if c == top2[1]]



subG_A = G.subgraph(comm_A)
center_A = max(subG_A.nodes(), key=lambda n: subG_A.degree(n))



def vote_label(community_nodes, anchor_labels):
    print(len(community_nodes))
    votes = [anchor_labels[str(n)] for n in community_nodes if str(n) in anchor_labels]
    print(len(votes))
    if not votes:
        return None  
    return Counter(votes).most_common(1)[0][0]

label_A = vote_label(comm_A, mapping_dict)  
print("lina")
label_B = vote_label(comm_B, mapping_dict)

print(label_A)
print(label_B)

predictions = {}
for node, comm in partition.items():

    if comm == top2[0]:
        predictions[node] = label_A
    elif comm == top2[1]:
        predictions[node] = label_B
# Out:
# 16026
# 38
# lina
# 13489
# 239
# 0
# 4

# %%
G.degree(weight='nb_retweeted')
# Out:
# DegreeView({1999: 2, 2355243272: 37, 4999: 2, 19624836: 38, 5034: 4, 2192533106: 9, 1019974187975430144: 524, 11113: 2, 15808647: 61, 11159: 3, 14075928: 44, 12301: 4, 16069119: 15, 13261: 4, 1090715513586679813: 614, 1320250946916651015: 1631, 13413: 2, 260478229: 2269, 13621: 2, 17773: 8, 80802900: 4841, 471287735: 1847, 545081356: 2109, 1189728422525915137: 2284, 20503: 6, 123504748: 25704, 22253: 3, 367132858: 1941, 22713: 2, 191074329: 144, 29283: 5, 37723353: 114, 306209103: 9, 36623: 2, 17852719: 170, 63243: 2, 69053: 57, 7215512: 92, 14050550: 163, 17793878: 216, 18696996: 10, 19539716: 269, 297688038: 7, 479724576: 60, 587875070: 15, 3308920474: 576, 811514954159443968: 21, 1351889468198965258: 9, 1450174360346574850: 285, 1494403156628819970: 8, 1508134569932836865: 18, 69583: 2, 137295176: 880, 73843: 2, 14223960: 40, 73963: 6, 4012161: 563, 76183: 2, 380648579: 547, 79553: 2, 193753: 2, 335523: 2, 367693: 3, 3094790117: 3, 381683: 2, 1094276372044800000: 120, 476083: 2, 8
# ...

# %%
def get_top_nodes(subGraphe,top_n) :
    degree=dict(subGraphe.degree(weight='nb_retweeted'))
    sortedNodes=sorted(degree.items(),key=lambda x :x[1] ,reverse =True)
    return [node for node,degree in sortedNodes[:top_n]]

# %%
subG_A=G.subgraph(comm_A)
top_1000_A = get_top_nodes(subG_A, 1000)
subG_B=G.subgraph(comm_B)
top_1000_B = get_top_nodes(subG_B, 1000)

# %%
df_labelA=pd.DataFrame({'Id':top_1000_A,'modularity_class': 0})
df_labelB=pd.DataFrame({'Id':top_1000_B,'modularity_class': 4})

df_label=pd.concat((df_labelA,df_labelB))
df_label.to_csv('nodes.csv',index=False,sep=";")
print(f"Fichier nodes.csv généré avec {len(df_label)} lignes.")
# Out:
# Fichier nodes.csv généré avec 2000 lignes.

# %%
partition = community_louvain.best_partition(G,resolution=0.01)



comm_sizes = Counter(partition.values())
top2 = [c for c, _ in comm_sizes.most_common(2)]
comm_A = [n for n, c in partition.items() if c == top2[0]]
comm_B = [n for n, c in partition.items() if c == top2[1]]



subG_A = G.subgraph(comm_A)
center_A = max(subG_A.nodes(), key=lambda n: subG_A.degree(n))



def vote_label(community_nodes, anchor_labels):

    votes = [anchor_labels[str(n)] for n in community_nodes if str(n) in anchor_labels]
    if not votes:
        return None  
    return Counter(votes).most_common(1)[0][0]

label_A = vote_label(comm_A, mapping_dict)  
label_B = vote_label(comm_B, mapping_dict)
print(label_A)
print(label_B)

predictions = {}
for node, comm in partition.items():

    if comm == top2[0]:
        predictions[node] = label_A
    elif comm == top2[1]:
        predictions[node] = label_B
    else:
        predictions[node] = None
# Out:
# None
# None

# %%
predictions

# %%
partition = community_louvain.best_partition(G,resolution=30)



comm_sizes = Counter(partition.values())
top2 = [c for c, _ in comm_sizes.most_common(4)]
comm_A = [n for n, c in partition.items() if c == top2[0]]
comm_B = [n for n, c in partition.items() if c == top2[1]]



subG_A = G.subgraph(comm_A)
center_A = max(subG_A.nodes(), key=lambda n: subG_A.degree(n))



def vote_label(community_nodes, anchor_labels):

    votes = [anchor_labels[str(n)] for n in community_nodes if str(n) in anchor_labels]
    if not votes:
        return None  
    return Counter(votes).most_common(1)[0][0]

label_A = vote_label(comm_A, mapping_dict)  
label_B = vote_label(comm_B, mapping_dict)
print(label_A)
print(label_B)

predictions = {}
for node, comm in partition.items():
    if comm == top2[0]:
        predictions[node] = label_A
    elif comm == top2[1]:
        predictions[node] = label_B
    else:
        predictions[node] = None

# %%
print(len(mapping_dict))

# %%
from networkx.algorithms.community import label_propagation_communities
communities=list(label_propagation_communities(G))

# %%
label=dict()
i=0
for k in communities :
    l=[c for j,c in mapping_dict.items() if int(j) in k]
    if l :

        
        label[i]=Counter(l).most_common(1)[0][0]

        
    i=i+1
