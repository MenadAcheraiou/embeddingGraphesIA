# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
import regression

# %%
fichier="NODES_climatoscope_graph_2022-07-01_2022-10-30_th=3.0_flc=0_world_2185-pro-anti_Louvaindic_testtop_tableusers.csv"

# %%
df["modularity_class"].unique()
# Out:
# array([4, 0], dtype=int64)

# %%
regression.regression(df)
# Out:
# Chargement des fichiers...
# Exemple ID Embedding nettoyé : 2986
# Exemple ID Label nettoyé     : 961997551015682048
#
# --- RÉSULTAT ---
# Utilisateurs communs trouvés : 538
# Données prêtes pour la régression : 538 lignes.
#
# Score de test :
#               precision    recall  f1-score   support
#
#   Pro-Climat       1.00      0.98      0.99        66
#    Sceptique       0.98      1.00      0.99        42
#
#     accuracy                           0.99       108
#    macro avg       0.99      0.99      0.99       108
# weighted avg       0.99      0.99      0.99       108
